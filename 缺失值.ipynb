# %%
# import Google Drive 套件
from google.colab import drive
# 將自己的雲端硬碟掛載上去
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
import pandas as pd
# 讀取資料集

train_data = pd.read_csv('gdrive/My Drive/titanic_train.csv')
test_data = pd.read_csv('gdrive/My Drive/titanic_test.csv')
# 列印資訊
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# 選擇用於訓練的特徵
features = ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']
x_train = train_data[features]
x_test = test_data[features]
y_train=train_data['Survived']

# %%
# 檢查缺失值
x_train.info()
print ('-'*100)
x_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    891 non-null    int64
#  1   Sex       891 non-null    object
#  2   Age       714 non-null    float64
#  3   SibSp     891 non-null    int64
#  4   Parch     891 non-null    int64
#  5   Fare      891 non-null    float64
#  6   Embarked  889 non-null    object
# dtypes: float64(2), int64(3), object(2)
# memory usage: 48.9+ KB
# ----------------------------------------------------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191 entries, 0 to 190
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    191 non-null    int64
#  1   Sex       191 non-null    object
#  2   Age       159 non-null    float64
#  3   SibSp     191 non-null    int64
#  4   Parch     191 non-null    int64
#  5   Fare      191 non-null    float64
#  6   Embarked  190 non-null    object
# dtypes: float64(2), int64(3), object(2)
# memory usage: 10.6+ KB

# %%
# 使用平均年齡來填充年齡中的nan值
x_train['Age'].fillna(x_train['Age'].mean(), inplace=True)
x_test['Age'].fillna(x_test['Age'].mean(),inplace=True)
# 使用票價的均值填充票價中的nan值
x_test['Fare'].fillna(x_test['Fare'].mean(),inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:4536: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,

# %%
# 訓練
boost.fit(x_train, y_train)
# 預測
y_predict = boost.predict(x_test)
# 儲存結果
result = {'PassengerId': test_data['PassengerId'],
'Survived': y_predict}
result = pd.DataFrame(result)
result.to_csv('submission.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-5d424563b089> in <module>()
#       1 # 訓練
# ----> 2 boost.fit(x_train, y_train)
#       3 # 預測
#       4 y_predict = boost.predict(x_test)
#       5 # 儲存結果
#
# NameError: name 'boost' is not defined
